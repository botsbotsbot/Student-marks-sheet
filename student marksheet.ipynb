# %% [markdown]
# # Student Marksheet

# %%
studentName = input("Enter student name: ")
std = str(input("Enter standard: "))
div = str(input("Enter division: "))
rollNumber = str(input("Enter roll number: "))
print("Marks achieved")
sub_1 = float(input("Subject 1 marks out of 100: "))
sub_2 = float(input("Subject 2 marks out of 100: "))
sub_3 = float(input("Subject 3 marks out of 100: "))
print('\n')
print("\tStudent Name  : ", student_name.upper())
print("\tStd & Div     : ", (std + '/' + div).upper())
print("\tRoll Number   : ", roll_number.upper())
print("\tMarks in sub 1: ", sub_1)
print("\tMarks in sub 2: ", sub_2)
print("\tMarks in sub 3: ", sub_3)
prct = ((sub_1 + sub_2 + sub_3) / 300) * 100
print("\tSum of marks  : ", str(sub_1 + sub_2 + sub_3) + " & " + "Percentage : ", "{:.3f}".format(prct))
# Out:
# Enter student name:  jhon
# Enter standard:  23
# Enter division:  a
# Enter roll number:  gdh456
# Marks achieved
# Subject 1 marks out of 100:  89
# Subject 2 marks out of 100:  91
# Subject 3 marks out of 100:  79
# 	Student Name  :  JHON
# 	Std & Div     :  23/A
# 	Roll Number   :  GDH456
# 	Marks in sub 1:  89.0
# 	Marks in sub 2:  91.0
# 	Marks in sub 3:  79.0
# 	Sum of marks  :  259.0 & Percentage :  86.333
